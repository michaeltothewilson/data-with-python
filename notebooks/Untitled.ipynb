# %% [markdown]
# # Accuracy, Precision, & Recall

# %%
import pandas as pd

# %%
# Data
pet_data = [
    {'breed': 'Siamese', 'species': 'Cat', 'weight_kg': 4.5},
    {'breed': 'Maine Coon', 'species': 'Cat', 'weight_kg': 8.0},
    {'breed': 'Persian', 'species': 'Cat', 'weight_kg': 5.5},
    {'breed': 'Sphynx', 'species': 'Cat', 'weight_kg': 4.0},
    {'breed': 'Ragdoll', 'species': 'Cat', 'weight_kg': 7.0},
    {'breed': 'Domestic Short Hair', 'species': 'Cat', 'weight_kg': 5.0},
    {'breed': 'Chihuahua', 'species': 'Dog', 'weight_kg': 2.5},
    {'breed': 'Yorkshire Terrier', 'species': 'Dog', 'weight_kg': 3.2},
    {'breed': 'Dachshund', 'species': 'Dog', 'weight_kg': 9.0},
    {'breed': 'Golden Retriever', 'species': 'Dog', 'weight_kg': 32.0}
]

# %%
from sk
