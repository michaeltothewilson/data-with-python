# %% [markdown]
# # Workout - Parking Tickets PDX
#
# ![Cars Parked in the City of Portland](../images/stock/pexels-brett-sayles-3995715.jpg)
# image credit: [Pexels](https://www.pexels.com)
#
# Ask and you shall receive...
#
# Early this term, I requested a years worth of parking data from [Portland's Public Records](https://www.portland.gov/public-records). With in a week, I was sent 250,000 rows of parking ticket data!

# %% [markdown]
# # 0. Importing and Inspecting the Data
#
# The files used for this workout is located at the following path:
#
# * Parking Violations CSV - `../data/parking_tickets_pdx/C455259_Data.csv`
# * Parking Violation Codes XLSX - `../data/parking_tickets_pdx/Offences.xlsx`
#
# Import the data and do the usual:
#
# - [ ] Inspect the dataset, looking for issues and quirks
# - [ ] Preview a few rows of data

# %%
### Your Solution

# %% [markdown]
# # 1. Cleaning
#
# Investigate the dataset and perform all of the necessary cleaning and modifications.
#
# Make sure that you have at least handled the following:
#
# - [ ] Null Values
# - [ ] Data Type Conversions
# - [ ] Column Naming Consistency
#
# __Consideration:__
#
# * How will you handle the `GPS` column?
# * How might you make  use of the Violation Codes in the `Offenses.xlsx` file and the `Offense 1` column in the larger dataset?

# %%
### Your Solution

# %% [markdown]
# # 2. Exploratory Data Analysis
#
# Now that your dataset is squeaky clean, what surface-level insights might you uncover?
#
# Perform at least 3 EDA-techniques to reveal some interesting or useful information within the data.
#
# This can include but is not limited to:
# * What are the numerical characteristics, such as the mean, min, and max, of the data?
# * Discover the n-smallest and n-largest values of various columns in the dataset
#     * This may reveal extreme values
# * Revealing frequent occurrences in the data
#     * Does a certain code, area, or value appear a significant amount of times? What might this imply?

# %%
### Your Solution

# %% [markdown]
# ### Your Observation(s)
#
# *
# *
# *

# %%
### Your Solution

# %% [markdown]
# ### Your Observation(s)
#
# *
# *
# *

# %%
### Your Solution

# %% [markdown]
# ### Your Observation(s)
#
# *
# *
# *

# %% [markdown]
# # 3. Visualizing the Data
#
# Okay, so you did some EDA, cool. But will the average person want to sift through raw numbers to get information? Probably not. So for their sake, create at least 5 unique visualizations to communicate insights and revelations based on the dataset.
#
# Here are two ideas for free:
# * [ ] Distribution of all relevant numerical data
# * [ ] Scatter Plot of all GPS coordinates (you did handle the `GPS` column...right?)
#
# What other visualizations will you conjure?
# * What information will they reveal?
# * What questions will they answer?

# %%
### Your Solution

# %% [markdown]
# ### Your Observation(s)
#
# *
# *
# *

# %%
### Your Solution

# %% [markdown]
# ### Your Observation(s)
#
# *
# *
# *

# %%
### Your Solution

# %% [markdown]
# ### Your Observation(s)
#
# *
# *
# *

# %%
### Your Solution

# %% [markdown]
# ### Your Observation(s)
#
# *
# *
# *

# %%
### Your Solution

# %% [markdown]
# ### Your Observation(s)
#
# *
# *
# *

# %% [markdown]
# # 4. Aggregating the Data
#
# What might the data reveal to us when we split up the data into separate groups?
#
# In the cells below, perform grouping and visualization to uncover new insights and revelations concerning Parking Violations in Portland.
#
# Here are a couple of questions to get you started:
#
# * At what time of day is parking enforcement the most frequent?
# * Which areas of Portland see the most tickets? Why might this be?

# %%
### Your Solution

# %% [markdown]
# ### Your Observation(s)
#
# *
# *
# *

# %%
### Your Solution

# %% [markdown]
# ### Your Observation(s)
#
# *
# *
# *

# %%
### Your Solution

# %% [markdown]
# ### Your Observation(s)
#
# *
# *
# *

# %%
### Your Solution

# %% [markdown]
# ### Your Observation(s)
#
# *
# *
# *

# %%
### Your Solution

# %% [markdown]
# ### Your Observation(s)
#
# *
# *
# *

# %% [markdown]
# # 5. Exporting the Data
#
# We may use this dataset in a future activity. Let's export the cleaned up version in order to save us time later on...

# %%
### Your Solution

# %% [markdown]
# # 6. Reflection
#
# Take some time to think, reflect, and discuss on this activity.
#
# * What did you learn today that was new for you?
# * Will the data and insights gained from today change how you go about your day-to-day in any way?
#     * If so, how?
#     * If not, why not?
# * How might today's discoveries be useful to people?
# * Did you label the axes of your visualizations?
