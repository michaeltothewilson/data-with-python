# %% [markdown]
# # Misleading Data
#
# Let's take a look at how legit data can be turned into misleading visuals.

# %% [markdown]
# ## The Dataset
#
# The data used in this notebook was gathered from the (FBI Crime Data Explorer)[https://cde.ucr.cjis.gov/]
#
# __Homicides in the United States__
#
# __file:__ `../data/exports/cleaned_homicide_data.csv`
#
# Contains 10 years of reported homicides in the United States.
#
# `Year` - The Year
# `Total_Count` - Total Count of homicides for the corresponding year
#
# __Robberies in the United States__
#
# __file:__ `../data/exports/cleaned_robbery_data.csv`
#
# Contains 10 years of reported robberies in the United States.
#
# `Year` - The Year
# `Total_Count` - Total Count of robberies for the corresponding year
#
# __Note:__
#
# Datasets were cleaned from their original download.
#
# __Cleaning:__
#
# * Modifying column names for consistency (removing white space & modifying casing)
# * Filtering Columns - kept the United States column, dropped `United States Clearances` and `United States Percent of Population Coverage`
# * Grouped the data by Year to show total count per year.

# %%
# Import
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load Data
file = "../data/exports/cleaned_homicide_data.csv"

homicides = pd.read_csv(file)

homicides
# Out:
#     year  count
# 0   2013  14114
# 1   2014  13966
# 2   2015  15643
# 3   2016  17123
# 4   2017  17466
# 5   2018  16853
# 6   2019  16694
# 7   2020  21587
# 8   2021  17909
# 9   2022  21868
# 10  2023  19713
# 11  2024  16991
# 12  2025   8513

# %% [markdown]
# # Murders in the United States

# %% [markdown]
# ## Inspect the Visualization Below 👀
#
# The Cell Below is a visualization based on the data that was imported.
#
# * What stories does the graph tell you?
# * How might the everyday person interpret this graph?
# * What is wrong with the graph?

# %%
# Filtering Data
mask = (homicides["year"] >= 2019) & (homicides["year"] <= 2020)
homicides_filtered = homicides[mask]

# Set Figure
plt.figure(figsize=(6,4))

# Generate Visualization
sns.barplot(
    data=homicides_filtered,
    x="year",
    y="count",
    palette="Set1",
    hue="year",
    legend=False)

plt.ylim(12500, 23000)

# Set Labels
plt.title("Reported Homicides in the United States")
plt.ylabel("Count")
plt.xlabel("Year")

plt.show()

# %% [markdown]
# ## Modify the Graph
#
# * Modify the code in the cell below to fix this poor excuse of data representation!!
# * What will you fix, how will you fix it?
# * How does the new graph compare to the previous graph????

# %%
############ Modify this Code ############
# Filtering Data
mask = (homicides["year"] >= 2014) & (homicides["year"] <= 2024)
homicides_filtered = homicides[mask]

# Set Figure
plt.figure(figsize=(6,4))

# Generate Visualization
sns.barplot(
    data=homicides_filtered,
    x="year",
    y="count",
    palette="dark:grey",
    hue="year",
    legend=False)

plt.ylim(0, 23000)

# Set Labels
plt.title("Reported Homicides in the United States")
plt.ylabel("Count")
plt.xlabel("Year")

plt.show()

# %% [markdown]
# ### Notes
#
# In order to keep this graph as honest as possible (compared to the previous version), we did the following:
#
# * __Y-Axis__ - Removed the limit to minimize the exaggeration between bar heights
# * __X-Axis__ - Expanded the range to include 2014-2024 to show the "bigger picture"
# * __2013__ - The difference in values for 2013 and 2014 seem rather suspicious. It felt like it made sense to leave out 2013.
# * __Color__ - Given the context of the subject, bright colors didn't feel right either

# %% [markdown]
# # Robberies in the United States

# %% [markdown]
# ## Inspect the Visualization Below 👀
#
# The Cell Below is a visualization based on the data that was imported.
#
# * What stories does the graph tell you?
# * How might the everyday person interpret this graph?
# * What is wrong with the graph?

# %%
# Load Data
file = "../data/exports/cleaned_robbery_data.csv"

robberies = pd.read_csv(file)

robberies.info()

robberies
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    11 non-null     int64
#  1   count   11 non-null     int64
# dtypes: int64(2)
# memory usage: 308.0 bytes
#     year  count
# 0   2015   4663
# 1   2016  17123
# 2   2017  17466
# 3   2018  16853
# 4   2019  16694
# 5   2020  21587
# 6   2021  17909
# 7   2022  21868
# 8   2023  19713
# 9   2024  16991
# 10  2025   8513

# %%
# Set Figure

# Import Ticker
import matplotlib.ticker as ticker

# Set Filter
mask = (robberies["year"] >= 2015) & (robberies["year"] <= 2016)
robberies_filtered = robberies[mask]

# Set Figure
plt.figure(figsize=(10,6))

# Generate Plot
sns.lineplot(
    data=robberies_filtered,
    x="year",
    y="count",
    color="blue")

plt.ylim(3000, 20000)

# Minor Modification to Keep the X-Axis as Integers
ax = plt.gca()
ax.xaxis.set_major_locator(ticker.MaxNLocator(integer=True))

# Set Titles and What not
plt.title("Reported Robberies in the United States")
plt.xlabel("Year")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ## Modify the Graph
#
# * FIX THIS GRAPH PLEASE

# %%
############ Modify this Code ############

# Set Filter
mask = (robberies["year"] >= 2016) & (robberies["year"] <= 2024)
robberies_filtered = robberies[mask]

# Set Figure
plt.figure(figsize=(10,6))

# Generate Plot
sns.lineplot(
    data=robberies_filtered,
    x="year",
    y="count",
    color="black")

plt.ylim(0, 30000)

# Minor Modification to Keep the X-Axis as Integers
ax = plt.gca()
ax.xaxis.set_major_locator(ticker.MaxNLocator(integer=True))

# Set Titles and What not
plt.title("Reported Robberies in the United States")
plt.xlabel("Year")
plt.ylabel("Count")
############ Modify this Code ############
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ### Notes
#
# In order to keep this graph as honest as possible (compared to the previous version), we did the following:
#
# * __Y-Axis__ - Made sure the Y-Axis started at zero to minimize exaggeration of the line's slope(s)
# * __X-Axis__ - Expanded the range to include 2016-2024 to show the "bigger picture"
# * __2015 & 2025__ - Once again we have years where the numbers seem too low when compared to the rest...so we left them out
# * __Color__ - Given the context of the subject, bright colors didn't feel right either
